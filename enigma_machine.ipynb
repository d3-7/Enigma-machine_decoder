# %%
class Rotor:
    def __init__(self, wiring, notch):
        self.wiring = wiring
        self.notch = notch
        self.position = 0

    def encrypt(self, char):
        shift = ord(char) - ord('A')
        shifted = (shift + self.position) % 26
        encrypted = self.wiring[shifted] + ord('A')
        return chr(encrypted)

    def decrypt(self, char):
        shift = ord(char) - ord('A')
        decrypted = self.wiring.index(shift) + ord('A')
        return chr(decrypted)

    def rotate(self):
        self.position = (self.position + 1) % 26


class EnigmaMachine:
    def __init__(self, rotors, reflector):
        self.rotors = rotors
        self.reflector = reflector

    def encrypt(self, message):
        encrypted_message = ''
        for char in message:
            if char.isalpha():
                char = char.upper()
                for rotor in self.rotors:
                    char = rotor.encrypt(char)
                char = self.reflector.encrypt(char)
                for rotor in reversed(self.rotors):
                    char = rotor.decrypt(char)
                encrypted_message += char
                for rotor in self.rotors:
                    if rotor.position == rotor.notch:
                        rotor.rotate()
                    rotor.rotate()
            else:
                encrypted_message += char
        return encrypted_message


# Define the rotor wirings and notches
rotor1_wiring = [4, 9, 12, 25, 0, 11, 24, 23, 21, 1, 22, 5, 2, 17, 16, 20, 14, 13, 19, 18, 15, 8, 10, 7, 6, 3]
rotor1_notch = 16

rotor2_wiring = [0, 9, 3, 10, 18, 8, 17, 20, 23, 1, 11, 7, 22, 19, 12, 2, 16, 6, 25, 13, 15, 24, 5, 21, 14, 4]
rotor2_notch = 4

rotor3_wiring = [1, 3, 5, 7, 9, 11, 2, 15, 17, 19, 23, 21, 25, 13, 24, 20, 18, 22, 10, 16, 8, 4, 6, 14, 12, 0]
rotor3_notch = 21

# Define the reflector wiring
reflector_wiring = [24, 17, 20, 7, 16, 18, 11, 3, 15, 23, 13, 6, 14, 10, 12, 8, 4, 1, 5, 25, 2, 22, 21, 9, 0, 19]

# Create the rotors and reflector
rotors = [
    Rotor(rotor1_wiring, rotor1_notch),
    Rotor(rotor2_wiring, rotor2_notch),
    Rotor(rotor3_wiring, rotor3_notch)
]
reflector = Rotor(reflector_wiring, 0)

# Create the Enigma machine
machine = EnigmaMachine(rotors, reflector)

# Get user input for the message to encrypt
message = input("Enter a message to encrypt: ").strip().upper()

# Try all possible rotor combinations
for rotor1_pos in range(26):
    for rotor2_pos in range(26):
        for rotor3_pos in range(26):
            # Set rotor positions
            rotors[0].position = rotor1_pos
            rotors[1].position = rotor2_pos
            rotors[2].position = rotor3_pos

            # Encrypt the message with current rotor positions
            encrypted_message = machine.encrypt(message)
            print(f"Positions: ({rotor1_pos}, {rotor2_pos}, {rotor3_pos}) | Encrypted message: {encrypted_message}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Positions: (18, 15, 18) | Encrypted message: NHLYX
# Positions: (18, 15, 19) | Encrypted message: UFMAE
# Positions: (18, 15, 20) | Encrypted message: WRBTQ
# Positions: (18, 15, 21) | Encrypted message: SIZND
# Positions: (18, 15, 22) | Encrypted message: HIZND
# Positions: (18, 15, 23) | Encrypted message: FVCUY
# Positions: (18, 15, 24) | Encrypted message: RGPWJ
# Positions: (18, 15, 25) | Encrypted message: KLXSA
# Positions: (18, 16, 0) | Encrypted message: MDMQK
# Positions: (18, 16, 1) | Encrypted message: OYODI
# Positions: (18, 16, 2) | Encrypted message: BJBYV
# Positions: (18, 16, 3) | Encrypted message: ZAZJG
# Positions: (18, 16, 4) | Encrypted message: CTCAL
# Positions: (18, 16, 5) | Encrypted message: PNPTM
# Positions: (18, 16, 6) | Encrypted message: XUXNO
# Positions: (18, 16, 7) | Encrypted message: EWEUB
# Positions: (18, 16, 8) | Encrypted message: QSQWZ
# Positions: (18, 16, 9) | Encrypted message: DHDSC
# Positions: (18, 16, 10) | Encrypted message: YFYHP
# Positions: (18, 16, 11) | Encrypted message: JRJFX
# Positions: (18, 16, 12) | Encrypted message: AKARE
# Positions: (18, 16, 13) | Encrypted message: TITKQ
# Positions: (18, 16, 14) | Encrypted message: NVNID
# Positions: (18, 16, 15) | Encrypted message: UGUVY
# Positions: (18, 16, 16) | Encrypted message: WLWGJ
# Positions: (18, 16, 17) | Encrypted message: SMSLA
# Positions: (18, 16, 18) | Encrypted message: HOHMN
# Positions: (18, 16, 19) | Encrypted message: FBFBU
# Positions: (18, 16, 20) | Encrypted message: RZKZW
# Positions: (18, 16, 21) | Encrypted message: KPICS
# Positions: (18, 16, 22) | Encrypted message: IPICS
# Positions: (18, 16, 23) | Encrypted message: VXVPH
# Positions: (18, 16, 24) | Encrypted message: GEGXF
# Positions: (18, 16, 25) | Encrypted message: LQLER
# Positions: (18, 17, 0) | Encrypted message: YZNOJ
# Positions: (18, 17, 1) | Encrypted message: JCUBA
# Positions: (18, 17, 2) | Encrypted message: APWZT
# Positions: (18, 17, 3) | Encrypted message: TXSCN
# Positions: (18, 17, 4) | Encrypted message: NEHPU
# Positions: (18, 17, 5) | Encrypted message: UQFXW
# Positions: (18, 17, 6) | Encrypted message: WDRES
# Positions: (18, 17, 7) | Encrypted message: SYKQH
# Positions: (18, 17, 8) | Encrypted message: HJIDF
# Positions: (18, 17, 9) | Encrypted message: FAVYR
# Positions: (18, 17, 10) | Encrypted message: RTGJK
# Positions: (18, 17, 11) | Encrypted message: KNLAI
# Positions: (18, 17, 12) | Encrypted message: IUMTV
# Positions: (18, 17, 13) | Encrypted message: VWONG
# Positions: (18, 17, 14) | Encrypted message: GSBUL
# Positions: (18, 17, 15) | Encrypted message: LHZWM
# Positions: (18, 17, 16) | Encrypted message: MFCSO
# Positions: (18, 17, 17) | Encrypted message: ORPHB
# Positions: (18, 17, 18) | Encrypted message: BKXFC
# Positions: (18, 17, 19) | Encrypted message: ZIEKP
# Positions: (18, 17, 20) | Encrypted message: CVDIX
# Positions: (18, 17, 21) | Encrypted message: PLYVE
# Positions: (18, 17, 22) | Encrypted message: XLYVE
# Positions: (18, 17, 23) | Encrypted message: EMJGQ
# Positions: (18, 17, 24) | Encrypted message: QOALD
# Positions: (18, 17, 25) | Encrypted message: DBTMY
# Positions: (18, 18, 0) | Encrypted message: XYWUR
# Positions: (18, 18, 1) | Encrypted message: EJSWK
# Positions: (18, 18, 2) | Encrypted message: QAHSI
# Positions: (18, 18, 3) | Encrypted message: DTFHV
# Positions: (18, 18, 4) | Encrypted message: YNRFG
# Positions: (18, 18, 5) | Encrypted message: JUKRL
# Positions: (18, 18, 6) | Encrypted message: AWIKM
# Positions: (18, 18, 7) | Encrypted message: TSVIO
# Positions: (18, 18, 8) | Encrypted message: NHGVB
# Positions: (18, 18, 9) | Encrypted message: UFLGZ
# Positions: (18, 18, 10) | Encrypted message: WRMLC
# Positions: (18, 18, 11) | Encrypted message: SKOMP
# Positions: (18, 18, 12) | Encrypted message: HIBOX
# Positions: (18, 18, 13) | Encrypted message: FVZBE
# Positions: (18, 18, 14) | Encrypted message: RGCZQ
# Positions: (18, 18, 15) | Encrypted message: KLPCD
# Positions: (18, 18, 16) | Encrypted message: IMXPY
# Positions: (18, 18, 17) | Encrypted message: VOEXJ
# Positions: (18, 18, 18) | Encrypted message: GBQET
# Positions: (18, 18, 19) | Encrypted message: LZDDN
# Positions: (18, 18, 20) | Encrypted message: MCJYU
# Positions: (18, 18, 21) | Encrypted message: OXAJW
# Positions: (18, 18, 22) | Encrypted message: BXAJW
# Positions: (18, 18, 23) | Encrypted message: ZETAS
# Positions: (18, 18, 24) | Encrypted message: CQNTH
# Positions: (18, 18, 25) | Encrypted message: PDUNF
# Positions: (18, 19, 0) | Encrypted message: KHLSV
# Positions: (18, 19, 1) | Encrypted message: IFMHG
# Positions: (18, 19, 2) | Encrypted message: VROFL
# Positions: (18, 19, 3) | Encrypted message: GKBRM
# Positions: (18, 19, 4) | Encrypted message: LIZKO
# Positions: (18, 19, 5) | Encrypted message: MVCIB
# Positions: (18, 19, 6) | Encrypted message: OGPVZ
# Positions: (18, 19, 7) | Encrypted message: BLXGC
# Positions: (18, 19, 8) | Encrypted message: ZMELP
# Positions: (18, 19, 9) | Encrypted message: COQMX
# Positions: (18, 19, 10) | Encrypted message: PBDOE
# Positions: (18, 19, 11) | Encrypted message: XZYBQ
# Positions: (18, 19, 12) | Encrypted message: ECJZD
# Positions: (18, 19, 13) | Encrypted message: QPACY
# Positions: (18, 19, 14) | Encrypted message: DXTPJ
# Positions: (18, 19, 15) | Encrypted message: YENXA
# Positions: (18, 19, 16) | Encrypted message: JQUET
# Positions: (18, 19, 17) | Encrypted message: ADWQN
# Positions: (18, 19, 18) | Encrypted message: TYSDW
# Positions: (18, 19, 19) | Encrypted message: NJHJS
# Positions: (18, 19, 20) | Encrypted message: UARAH
# Positions: (18, 19, 21) | Encrypted message: WNKTF
# Positions: (18, 19, 22) | Encrypted message: SNKTF
# Positions: (18, 19, 23) | Encrypted message: HUINR
# Positions: (18, 19, 24) | Encrypted message: FWVUK
# Positions: (18, 19, 25) | Encrypted message: RSGWI
# Positions: (18, 20, 0) | Encrypted message: HQXMM
# Positions: (18, 20, 1) | Encrypted message: FDEOO
# Positions: (18, 20, 2) | Encrypted message: RYQBB
# Positions: (18, 20, 3) | Encrypted message: KJDZZ
# Positions: (18, 20, 4) | Encrypted message: IAYCC
# Positions: (18, 20, 5) | Encrypted message: VTJPP
# Positions: (18, 20, 6) | Encrypted message: GNAXX
# Positions: (18, 20, 7) | Encrypted message: LUTEE
# Positions: (18, 20, 8) | Encrypted message: MWNQQ
# Positions: (18, 20, 9) | Encrypted message: OSUDD
# Positions: (18, 20, 10) | Encrypted message: BHWYY
# Positions: (18, 20, 11) | Encrypted message: ZFSJJ
# Positions: (18, 20, 12) | Encrypted message: CRHAA
# Positions: (18, 20, 13) | Encrypted message: PKFTT
# Positions: (18, 20, 14) | Encrypted message: XIRNN
# Positions: (18, 20, 15) | Encrypted message: EVKUU
# Positions: (18, 20, 16) | Encrypted message: QGIWW
# Positions: (18, 20, 17) | Encrypted message: DLVSS
# Positions: (18, 20, 18) | Encrypted message: YMGHF
# Positions: (18, 20, 19) | Encrypted message: JOLRR
# Positions: (18, 20, 20) | Encrypted message: ABOKK
# Positions: (18, 20, 21) | Encrypted message: TCBII
# Positions: (18, 20, 22) | Encrypted message: NCBII
# Positions: (18, 20, 23) | Encrypted message: UPZVV
# Positions: (18, 20, 24) | Encrypted message: WXCGG
# Positions: (18, 20, 25) | Encrypted message: SEPLL
# Positions: (18, 21, 0) | Encrypted message: JSIEC
# Positions: (18, 21, 1) | Encrypted message: AHVQP
# Positions: (18, 21, 2) | Encrypted message: TFGDX
# Positions: (18, 21, 3) | Encrypted message: NRLYE
# Positions: (18, 21, 4) | Encrypted message: UKMJQ
# Positions: (18, 21, 5) | Encrypted message: WIOAD
# Positions: (18, 21, 6) | Encrypted message: SVBTY
# Positions: (18, 21, 7) | Encrypted message: HGZNJ
# Positions: (18, 21, 8) | Encrypted message: FLCUA
# Positions: (18, 21, 9) | Encrypted message: RMPWT
# Positions: (18, 21, 10) | Encrypted message: KOXSN
# Positions: (18, 21, 11) | Encrypted message: IBEHU
# Positions: (18, 21, 12) | Encrypted message: VZQFW
# Positions: (18, 21, 13) | Encrypted message: GCDRS
# Positions: (18, 21, 14) | Encrypted message: LPYKH
# Positions: (18, 21, 15) | Encrypted message: MXJIF
# Positions: (18, 21, 16) | Encrypted message: OEAVR
# Positions: (18, 21, 17) | Encrypted message: BQTGK
# Positions: (18, 21, 18) | Encrypted message: ZDNLV
# Positions: (18, 21, 19) | Encrypted message: CYUOG
# Positions: (18, 21, 20) | Encrypted message: PJSBL
# Positions: (18, 21, 21) | Encrypted message: XTHZM
# Positions: (18, 21, 22) | Encrypted message: ETHZM
# Positions: (18, 21, 23) | Encrypted message: QNFCO
# Positions: (18, 21, 24) | Encrypted message: DURPB
# Positions: (18, 21, 25) | Encrypted message: YWKXZ
# Positions: (18, 22, 0) | Encrypted message: ORUVN
# Positions: (18, 22, 1) | Encrypted message: BKWGU
# Positions: (18, 22, 2) | Encrypted message: ZISLW
# Positions: (18, 22, 3) | Encrypted message: CVHMS
# Positions: (18, 22, 4) | Encrypted message: PGFOH
# Positions: (18, 22, 5) | Encrypted message: XLRBF
# Positions: (18, 22, 6) | Encrypted message: EMKZR
# Positions: (18, 22, 7) | Encrypted message: QOICK
# Positions: (18, 22, 8) | Encrypted message: DBVPI
# Positions: (18, 22, 9) | Encrypted message: YZGXV
# Positions: (18, 22, 10) | Encrypted message: JCLEG
# Positions: (18, 22, 11) | Encrypted message: APMQL
# Positions: (18, 22, 12) | Encrypted message: TXODM
# Positions: (18, 22, 13) | Encrypted message: NEBYO
# Positions: (18, 22, 14) | Encrypted message: UQZJB
# Positions: (18, 22, 15) | Encrypted message: WDCAZ
# Positions: (18, 22, 16) | Encrypted message: SYPTC
# Positions: (18, 22, 17) | Encrypted message: HJXNP
# Positions: (18, 22, 18) | Encrypted message: FAEUE
# Positions: (18, 22, 19) | Encrypted message: RTQSQ
# Positions: (18, 22, 20) | Encrypted message: KNYHD
# Positions: (18, 22, 21) | Encrypted message: IWJFY
# Positions: (18, 22, 22) | Encrypted message: VWJFY
# Positions: (18, 22, 23) | Encrypted message: GSARJ
# Positions: (18, 22, 24) | Encrypted message: LHTKA
# Positions: (18, 22, 25) | Encrypted message: MFNIT
# Positions: (18, 23, 0) | Encrypted message: UVPWY
# Positions: (18, 23, 1) | Encrypted message: WGXSJ
# Positions: (18, 23, 2) | Encrypted message: SLEHA
# Positions: (18, 23, 3) | Encrypted message: HMQFT
# Positions: (18, 23, 4) | Encrypted message: FODRN
# Positions: (18, 23, 5) | Encrypted message: RBYKU
# Positions: (18, 23, 6) | Encrypted message: KZJIW
# Positions: (18, 23, 7) | Encrypted message: ICAVS
# Positions: (18, 23, 8) | Encrypted message: VPTGH
# Positions: (18, 23, 9) | Encrypted message: GXNLF
# Positions: (18, 23, 10) | Encrypted message: LEUMR
# Positions: (18, 23, 11) | Encrypted message: MQWOK
# Positions: (18, 23, 12) | Encrypted message: ODSBI
# Positions: (18, 23, 13) | Encrypted message: BYHZV
# Positions: (18, 23, 14) | Encrypted message: ZJFCG
# Positions: (18, 23, 15) | Encrypted message: CARPL
# Positions: (18, 23, 16) | Encrypted message: PTKXM
# Positions: (18, 23, 17) | Encrypted message: XNIEO
# Positions: (18, 23, 18) | Encrypted message: EUVQZ
# Positions: (18, 23, 19) | Encrypted message: QWGYC
# Positions: (18, 23, 20) | Encrypted message: DSMJP
# Positions: (18, 23, 21) | Encrypted message: YFOAX
# Positions: (18, 23, 22) | Encrypted message: JFOAX
# Positions: (18, 23, 23) | Encrypted message: ARBTE
# Positions: (18, 23, 24) | Encrypted message: TKZNQ
# Positions: (18, 23, 25) | Encrypted message: NICUD
# Positions: (18, 24, 0) | Encrypted message: POOXL
# Positions: (18, 24, 1) | Encrypted message: XBBEM
# Positions: (18, 24, 2) | Encrypted message: EZZQO
# Positions: (18, 24, 3) | Encrypted message: QCCDB
# Positions: (18, 24, 4) | Encrypted message: DPPYZ
# Positions: (18, 24, 5) | Encrypted message: YXXJC
# Positions: (18, 24, 6) | Encrypted message: JEEAP
# Positions: (18, 24, 7) | Encrypted message: AQQTX
# Positions: (18, 24, 8) | Encrypted message: TDDNE
# Positions: (18, 24, 9) | Encrypted message: NYYUQ
# Positions: (18, 24, 10) | Encrypted message: UJJWD
# Positions: (18, 24, 11) | Encrypted message: WAASY
# Positions: (18, 24, 12) | Encrypted message: STTHJ
# Positions: (18, 24, 13) | Encrypted message: HNNFA
# Positions: (18, 24, 14) | Encrypted message: FUURT
# Positions: (18, 24, 15) | Encrypted message: RWWKN
# Positions: (18, 24, 16) | Encrypted message: KSSIU
# Positions: (18, 24, 17) | Encrypted message: IHHVW
# Positions: (18, 24, 18) | Encrypted message: VFFGH
# Positions: (18, 24, 19) | Encrypted message: GRRMF
# Positions: (18, 24, 20) | Encrypted message: LKIOR
# Positions: (18, 24, 21) | Encrypted message: MVVBK
# Positions: (18, 24, 22) | Encrypted message: OVVBK
# Positions: (18, 24, 23) | Encrypted message: BGGZI
# Positions: (18, 24, 24) | Encrypted message: ZLLCV
# Positions: (18, 24, 25) | Encrypted message: CMMPG
# Positions: (18, 25, 0) | Encrypted message: GJYBI
# Positions: (18, 25, 1) | Encrypted message: LAJZV
# Positions: (18, 25, 2) | Encrypted message: MTACG
# Positions: (18, 25, 3) | Encrypted message: ONTPL
# Positions: (18, 25, 4) | Encrypted message: BUNXM
# Positions: (18, 25, 5) | Encrypted message: ZWUEO
# Positions: (18, 25, 6) | Encrypted message: CSWQB
# Positions: (18, 25, 7) | Encrypted message: PHSDZ
# Positions: (18, 25, 8) | Encrypted message: XFHYC
# Positions: (18, 25, 9) | Encrypted message: ERFJP
# Positions: (18, 25, 10) | Encrypted message: QKRAX
# Positions: (18, 25, 11) | Encrypted message: DIKTE
# Positions: (18, 25, 12) | Encrypted message: YVINQ
# Positions: (18, 25, 13) | Encrypted message: JGVUD
# Positions: (18, 25, 14) | Encrypted message: ALGWY
# Positions: (18, 25, 15) | Encrypted message: TMLSJ
# Positions: (18, 25, 16) | Encrypted message: NOMHA
# Positions: (18, 25, 17) | Encrypted message: UBOFT
# Positions: (18, 25, 18) | Encrypted message: WZBRU
# Positions: (18, 25, 19) | Encrypted message: SCZIW
# Positions: (18, 25, 20) | Encrypted message: HPPVS
# Positions: (18, 25, 21) | Encrypted message: FEXGH
# Positions: (18, 25, 22) | Encrypted message: REXGH
# Positions: (18, 25, 23) | Encrypted message: KQELF
# Positions: (18, 25, 24) | Encrypted message: IDQMR
# Positions: (18, 25, 25) | Encrypted message: VYDOK
# Positions: (19, 0, 0) | Encrypted message: GVRBY
# Positions: (19, 0, 1) | Encrypted message: LGKZJ
# Positions: (19, 0, 2) | Encrypted message: MLICA
# Positions: (19, 0, 3) | Encrypted message: OMVPT
# Positions: (19, 0, 4) | Encrypted message: BOGXN
# Positions: (19, 0, 5) | Encrypted message: ZBLEU
# Positions: (19, 0, 6) | Encrypted message: CZMQW
# Positions: (19, 0, 7) | Encrypted message: PCODS
# Positions: (19, 0, 8) | Encrypted message: XPBYH
# Positions: (19, 0, 9) | Encrypted message: EXZJF
# Positions: (19, 0, 10) | Encrypted message: QECAR
# Positions: (19, 0, 11) | Encrypted message: DQPTK
# Positions: (19, 0, 12) | Encrypted message: YDXNI
# Positions: (19, 0, 13) | Encrypted message: JYEUV
# Positions: (19, 0, 14) | Encrypted message: AJQWG
# Positions: (19, 0, 15) | Encrypted message: TADSL
# Positions: (19, 0, 16) | Encrypted message: NTYHM
# Positions: (19, 0, 17) | Encrypted message: UNJFO
# Positions: (19, 0, 18) | Encrypted message: WUARZ
# Positions: (19, 0, 19) | Encrypted message: SWTIC
# Positions: (19, 0, 20) | Encrypted message: HSUVP
# Positions: (19, 0, 21) | Encrypted message: FFWGX
# Positions: (19, 0, 22) | Encrypted message: RFWGX
# Positions: (19, 0, 23) | Encrypted message: KRSLE
# Positions: (19, 0, 24) | Encrypted message: IKHMQ
# Positions: (19, 0, 25) | Encrypted message: VIFOD
# Positions: (19, 1, 0) | Encrypted message: AOTJI
# Positions: (19, 1, 1) | Encrypted message: TBNAV
# Positions: (19, 1, 2) | Encrypted message: NZUTG
# Positions: (19, 1, 3) | Encrypted message: UCWNL
# Positions: (19, 1, 4) | Encrypted message: WPSUM
# Positions: (19, 1, 5) | Encrypted message: SXHWO
# Positions: (19, 1, 6) | Encrypted message: HEFSB
# Positions: (19, 1, 7) | Encrypted message: FQRHZ
# Positions: (19, 1, 8) | Encrypted message: RDKFC
# Positions: (19, 1, 9) | Encrypted message: KYIRP
# Positions: (19, 1, 10) | Encrypted message: IJVKX
# Positions: (19, 1, 11) | Encrypted message: VAGIE
# Positions: (19, 1, 12) | Encrypted message: GTLVQ
# Positions: (19, 1, 13) | Encrypted message: LNMGD
# Positions: (19, 1, 14) | Encrypted message: MUOLY
# Positions: (19, 1, 15) | Encrypted message: OWBMJ
# Positions: (19, 1, 16) | Encrypted message: BSZOA
# Positions: (19, 1, 17) | Encrypted message: ZHCBT
# Positions: (19, 1, 18) | Encrypted message: CFPZU
# Positions: (19, 1, 19) | Encrypted message: PRXPW
# Positions: (19, 1, 20) | Encrypted message: XKQXS
# Positions: (19, 1, 21) | Encrypted message: EVDEH
# Positions: (19, 1, 22) | Encrypted message: QVDEH
# Positions: (19, 1, 23) | Encrypted message: DGYQF
# Positions: (19, 1, 24) | Encrypted message: YLJDR
# Positions: (19, 1, 25) | Encrypted message: JMAYK
# Positions: (19, 2, 0) | Encrypted message: NJZAU
# Positions: (19, 2, 1) | Encrypted message: UACTW
# Positions: (19, 2, 2) | Encrypted message: WTPNS
# Positions: (19, 2, 3) | Encrypted message: SNXUH
# Positions: (19, 2, 4) | Encrypted message: HUEWF
# Positions: (19, 2, 5) | Encrypted message: FWQSR
# Positions: (19, 2, 6) | Encrypted message: RSDHK
# Positions: (19, 2, 7) | Encrypted message: KHYFI
# Positions: (19, 2, 8) | Encrypted message: IFJRV
# Positions: (19, 2, 9) | Encrypted message: VRAKG
# Positions: (19, 2, 10) | Encrypted message: GKTIL
# Positions: (19, 2, 11) | Encrypted message: LINVM
# Positions: (19, 2, 12) | Encrypted message: MVUGO
# Positions: (19, 2, 13) | Encrypted message: OGWLB
# Positions: (19, 2, 14) | Encrypted message: BLSMZ
# Positions: (19, 2, 15) | Encrypted message: ZMHOC
# Positions: (19, 2, 16) | Encrypted message: COFBP
# Positions: (19, 2, 17) | Encrypted message: PBRZX
# Positions: (19, 2, 18) | Encrypted message: XZKCQ
# Positions: (19, 2, 19) | Encrypted message: ECIXD
# Positions: (19, 2, 20) | Encrypted message: QPGEY
# Positions: (19, 2, 21) | Encrypted message: DELQJ
# Positions: (19, 2, 22) | Encrypted message: YELQJ
# Positions: (19, 2, 23) | Encrypted message: JQMDA
# Positions: (19, 2, 24) | Encrypted message: ADOYT
# Positions: (19, 2, 25) | Encrypted message: TYBJN
# Positions: (19, 3, 0) | Encrypted message: VEERP
# Positions: (19, 3, 1) | Encrypted message: GQQKX
# Positions: (19, 3, 2) | Encrypted message: LDDIE
# Positions: (19, 3, 3) | Encrypted message: MYYVQ
# Positions: (19, 3, 4) | Encrypted message: OJJGD
# Positions: (19, 3, 5) | Encrypted message: BAALY
# Positions: (19, 3, 6) | Encrypted message: ZTTMJ
# Positions: (19, 3, 7) | Encrypted message: CNNOA
# Positions: (19, 3, 8) | Encrypted message: PUUBT
# Positions: (19, 3, 9) | Encrypted message: XWWZN
# Positions: (19, 3, 10) | Encrypted message: ESSCU
# Positions: (19, 3, 11) | Encrypted message: QHHPW
# Positions: (19, 3, 12) | Encrypted message: DFFXS
# Positions: (19, 3, 13) | Encrypted message: YRREH
# Positions: (19, 3, 14) | Encrypted message: JKKQF
# Positions: (19, 3, 15) | Encrypted message: AIIDR
# Positions: (19, 3, 16) | Encrypted message: TVVYK
# Positions: (19, 3, 17) | Encrypted message: NGGJI
# Positions: (19, 3, 18) | Encrypted message: ULLAG
# Positions: (19, 3, 19) | Encrypted message: WMMNL
# Positions: (19, 3, 20) | Encrypted message: SOBUM
# Positions: (19, 3, 21) | Encrypted message: HZZWO
# Positions: (19, 3, 22) | Encrypted message: FZZWO
# Positions: (19, 3, 23) | Encrypted message: RCCSB
# Positions: (19, 3, 24) | Encrypted message: KPPHZ
# Positions: (19, 3, 25) | Encrypted message: IXXFC
# Positions: (19, 4, 0) | Encrypted message: CFMYF
# Positions: (19, 4, 1) | Encrypted message: PROJR
# Positions: (19, 4, 2) | Encrypted message: XKBAK
# Positions: (19, 4, 3) | Encrypted message: EIZTI
# Positions: (19, 4, 4) | Encrypted message: QVCNV
# Positions: (19, 4, 5) | Encrypted message: DGPUG
# Positions: (19, 4, 6) | Encrypted message: YLXWL
# Positions: (19, 4, 7) | Encrypted message: JMESM
# Positions: (19, 4, 8) | Encrypted message: AOQHO
# Positions: (19, 4, 9) | Encrypted message: TBDFB
# Positions: (19, 4, 10) | Encrypted message: NZYRZ
# Positions: (19, 4, 11) | Encrypted message: UCJKC
# Positions: (19, 4, 12) | Encrypted message: WPAIP
# Positions: (19, 4, 13) | Encrypted message: SXTVX
# Positions: (19, 4, 14) | Encrypted message: HENGE
# Positions: (19, 4, 15) | Encrypted message: FQULQ
# Positions: (19, 4, 16) | Encrypted message: RDWMD
# Positions: (19, 4, 17) | Encrypted message: KYSOY
# Positions: (19, 4, 18) | Encrypted message: IJHBA
# Positions: (19, 4, 19) | Encrypted message: VAFCT
# Positions: (19, 4, 20) | Encrypted message: GTKPN
# Positions: (19, 4, 21) | Encrypted message: LUIXU
# Positions: (19, 4, 22) | Encrypted message: MUIXU
# Positions: (19, 4, 23) | Encrypted message: OWVEW
# Positions: (19, 4, 24) | Encrypted message: BSGQS
# Positions: (19, 4, 25) | Encrypted message: ZHLDH
# Positions: (19, 5, 0) | Encrypted message: RFMYF
# Positions: (19, 5, 1) | Encrypted message: KROJR
# Positions: (19, 5, 2) | Encrypted message: IKBAK
# Positions: (19, 5, 3) | Encrypted message: VIZTI
# Positions: (19, 5, 4) | Encrypted message: GVCNV
# Positions: (19, 5, 5) | Encrypted message: LGPUG
# Positions: (19, 5, 6) | Encrypted message: MLXWL
# Positions: (19, 5, 7) | Encrypted message: OMESM
# Positions: (19, 5, 8) | Encrypted message: BOQHO
# Positions: (19, 5, 9) | Encrypted message: ZBDFB
# Positions: (19, 5, 10) | Encrypted message: CZYRZ
# Positions: (19, 5, 11) | Encrypted message: PCJKC
# Positions: (19, 5, 12) | Encrypted message: XPAIP
# Positions: (19, 5, 13) | Encrypted message: EXTVX
# Positions: (19, 5, 14) | Encrypted message: QENGE
# Positions: (19, 5, 15) | Encrypted message: DQULQ
# Positions: (19, 5, 16) | Encrypted message: YDWMD
# Positions: (19, 5, 17) | Encrypted message: JYSOY
# Positions: (19, 5, 18) | Encrypted message: AJHBA
# Positions: (19, 5, 19) | Encrypted message: TAFCT
# Positions: (19, 5, 20) | Encrypted message: NTKPN
# Positions: (19, 5, 21) | Encrypted message: UUIXU
# Positions: (19, 5, 22) | Encrypted message: WUIXU
# Positions: (19, 5, 23) | Encrypted message: SWVEW
# Positions: (19, 5, 24) | Encrypted message: HSGQS
# Positions: (19, 5, 25) | Encrypted message: FHLDH
# Positions: (19, 6, 0) | Encrypted message: TANFD
# Positions: (19, 6, 1) | Encrypted message: NTURY
# Positions: (19, 6, 2) | Encrypted message: UNWKJ
# Positions: (19, 6, 3) | Encrypted message: WUSIA
# Positions: (19, 6, 4) | Encrypted message: SWHVT
# Positions: (19, 6, 5) | Encrypted message: HSFGN
# Positions: (19, 6, 6) | Encrypted message: FHRLU
# Positions: (19, 6, 7) | Encrypted message: RFKMW
# Positions: (19, 6, 8) | Encrypted message: KRIOS
# Positions: (19, 6, 9) | Encrypted message: IKVBH
# Positions: (19, 6, 10) | Encrypted message: VIGZF
# Positions: (19, 6, 11) | Encrypted message: GVLCR
# Positions: (19, 6, 12) | Encrypted message: LGMPK
# Positions: (19, 6, 13) | Encrypted message: MLOXI
# Positions: (19, 6, 14) | Encrypted message: OMBEV
# Positions: (19, 6, 15) | Encrypted message: BOZQG
# Positions: (19, 6, 16) | Encrypted message: ZBCDL
# Positions: (19, 6, 17) | Encrypted message: CZPYM
# Positions: (19, 6, 18) | Encrypted message: PCXJB
# Positions: (19, 6, 19) | Encrypted message: XPETZ
# Positions: (19, 6, 20) | Encrypted message: EXDNC
# Positions: (19, 6, 21) | Encrypted message: QQYUP
# Positions: (19, 6, 22) | Encrypted message: DQYUP
# Positions: (19, 6, 23) | Encrypted message: YDJWX
# Positions: (19, 6, 24) | Encrypted message: JYASE
# Positions: (19, 6, 25) | Encrypted message: AJTHQ
# Positions: (19, 7, 0) | Encrypted message: ZBWIB
# Positions: (19, 7, 1) | Encrypted message: CZSVZ
# Positions: (19, 7, 2) | Encrypted message: PCHGC
# Positions: (19, 7, 3) | Encrypted message: XPFLP
# Positions: (19, 7, 4) | Encrypted message: EXRMX
# Positions: (19, 7, 5) | Encrypted message: QEKOE
# Positions: (19, 7, 6) | Encrypted message: DQIBQ
# Positions: (19, 7, 7) | Encrypted message: YDVZD
# Positions: (19, 7, 8) | Encrypted message: JYGCY
# Positions: (19, 7, 9) | Encrypted message: AJLPJ
# Positions: (19, 7, 10) | Encrypted message: TAMXA
# Positions: (19, 7, 11) | Encrypted message: NTOET
# Positions: (19, 7, 12) | Encrypted message: UNBQN
# Positions: (19, 7, 13) | Encrypted message: WUZDU
# Positions: (19, 7, 14) | Encrypted message: SWCYW
# Positions: (19, 7, 15) | Encrypted message: HSPJS
# Positions: (19, 7, 16) | Encrypted message: FHXAH
# Positions: (19, 7, 17) | Encrypted message: RFETF
# Positions: (19, 7, 18) | Encrypted message: KRQNK
# Positions: (19, 7, 19) | Encrypted message: IKDWI
# Positions: (19, 7, 20) | Encrypted message: VIJSV
# Positions: (19, 7, 21) | Encrypted message: GGAHG
# Positions: (19, 7, 22) | Encrypted message: LGAHG
# Positions: (19, 7, 23) | Encrypted message: MLTFL
# Positions: (19, 7, 24) | Encrypted message: OMNRM
# Positions: (19, 7, 25) | Encrypted message: BOUKO
# Positions: (19, 8, 0) | Encrypted message: LWLLW
# Positions: (19, 8, 1) | Encrypted message: MSMMS
# Positions: (19, 8, 2) | Encrypted message: OHOOH
# Positions: (19, 8, 3) | Encrypted message: BFBBF
# Positions: (19, 8, 4) | Encrypted message: ZRZZR
# Positions: (19, 8, 5) | Encrypted message: CKCCK
# Positions: (19, 8, 6) | Encrypted message: PIPPI
# Positions: (19, 8, 7) | Encrypted message: XVXXV
# Positions: (19, 8, 8) | Encrypted message: EGEEG
# Positions: (19, 8, 9) | Encrypted message: QLQQL
# Positions: (19, 8, 10) | Encrypted message: DMDDM
# Positions: (19, 8, 11) | Encrypted message: YOYYO
# Positions: (19, 8, 12) | Encrypted message: JBJJB
# Positions: (19, 8, 13) | Encrypted message: AZAAZ
# Positions: (19, 8, 14) | Encrypted message: TCTTC
# Positions: (19, 8, 15) | Encrypted message: NPNNP
# Positions: (19, 8, 16) | Encrypted message: UXUUX
# Positions: (19, 8, 17) | Encrypted message: WEWWE
# Positions: (19, 8, 18) | Encrypted message: SQSSD
# Positions: (19, 8, 19) | Encrypted message: HDHFY
# Positions: (19, 8, 20) | Encrypted message: FYRRJ
# Positions: (19, 8, 21) | Encrypted message: RAKKA
# Positions: (19, 8, 22) | Encrypted message: KAKKA
# Positions: (19, 8, 23) | Encrypted message: ITIIT
# Positions: (19, 8, 24) | Encrypted message: VNVVN
# Positions: (19, 8, 25) | Encrypted message: GUGGU
# Positions: (19, 9, 0) | Encrypted message: QXXZH
# Positions: (19, 9, 1) | Encrypted message: DEECF
# Positions: (19, 9, 2) | Encrypted message: YQQPR
# Positions: (19, 9, 3) | Encrypted message: JDDXK
# Positions: (19, 9, 4) | Encrypted message: AYYEI
# Positions: (19, 9, 5) | Encrypted message: TJJQV
# Positions: (19, 9, 6) | Encrypted message: NAADG
# Positions: (19, 9, 7) | Encrypted message: UTTYL
# Positions: (19, 9, 8) | Encrypted message: WNNJM
# Positions: (19, 9, 9) | Encrypted message: SUUAO
# Positions: (19, 9, 10) | Encrypted message: HWWTB
# Positions: (19, 9, 11) | Encrypted message: FSSNZ
# Positions: (19, 9, 12) | Encrypted message: RHHUC
# Positions: (19, 9, 13) | Encrypted message: KFFWP
# Positions: (19, 9, 14) | Encrypted message: IRRSX
# Positions: (19, 9, 15) | Encrypted message: VKKHE
# Positions: (19, 9, 16) | Encrypted message: GIIFQ
# Positions: (19, 9, 17) | Encrypted message: LVVRD
# Positions: (19, 9, 18) | Encrypted message: MGGKJ
# Positions: (19, 9, 19) | Encrypted message: OLLVA
# Positions: (19, 9, 20) | Encrypted message: BMOGT
# Positions: (19, 9, 21) | Encrypted message: ZBBLN
# Positions: (19, 9, 22) | Encrypted message: CBBLN
# Positions: (19, 9, 23) | Encrypted message: PZZMU
# Positions: (19, 9, 24) | Encrypted message: XCCOW
# Positions: (19, 9, 25) | Encrypted message: EPPBS
# Positions: (19, 10, 0) | Encrypted message: BLITO
# Positions: (19, 10, 1) | Encrypted message: ZMVNB
# Positions: (19, 10, 2) | Encrypted message: COGUZ
# Positions: (19, 10, 3) | Encrypted message: PBLWC
# Positions: (19, 10, 4) | Encrypted message: XZMSP
# Positions: (19, 10, 5) | Encrypted message: ECOHX
# Positions: (19, 10, 6) | Encrypted message: QPBFE
# Positions: (19, 10, 7) | Encrypted message: DXZRQ
# Positions: (19, 10, 8) | Encrypted message: YECKD
# Positions: (19, 10, 9) | Encrypted message: JQPIY
# Positions: (19, 10, 10) | Encrypted message: ADXVJ
# Positions: (19, 10, 11) | Encrypted message: TYEGA
# Positions: (19, 10, 12) | Encrypted message: NJQLT
# Positions: (19, 10, 13) | Encrypted message: UADMN
# Positions: (19, 10, 14) | Encrypted message: WTYOU
# Positions: (19, 10, 15) | Encrypted message: SNJBW
# Positions: (19, 10, 16) | Encrypted message: HUAZS
# Positions: (19, 10, 17) | Encrypted message: FWTCH
# Positions: (19, 10, 18) | Encrypted message: RSNPR
# Positions: (19, 10, 19) | Encrypted message: KHUEK
# Positions: (19, 10, 20) | Encrypted message: IFSQI
# Positions: (19, 10, 21) | Encrypted message: VKHDV
# Positions: (19, 10, 22) | Encrypted message: GKHDV
# Positions: (19, 10, 23) | Encrypted message: LIFYG
# Positions: (19, 10, 24) | Encrypted message: MVRJL
# Positions: (19, 10, 25) | Encrypted message: OGKAM
# Positions: (19, 11, 0) | Encrypted message: DTUDQ
# Positions: (19, 11, 1) | Encrypted message: YNWYD
# Positions: (19, 11, 2) | Encrypted message: JUSJY
# Positions: (19, 11, 3) | Encrypted message: AWHAJ
# Positions: (19, 11, 4) | Encrypted message: TSFTA
# Positions: (19, 11, 5) | Encrypted message: NHRNT
# Positions: (19, 11, 6) | Encrypted message: UFKUN
# Positions: (19, 11, 7) | Encrypted message: WRIWU
# Positions: (19, 11, 8) | Encrypted message: SKVSW
# Positions: (19, 11, 9) | Encrypted message: HIGHS
# Positions: (19, 11, 10) | Encrypted message: FVLFH
# Positions: (19, 11, 11) | Encrypted message: RGMRF
# Positions: (19, 11, 12) | Encrypted message: KLOKR
# Positions: (19, 11, 13) | Encrypted message: IMBIK
# Positions: (19, 11, 14) | Encrypted message: VOZVI
# Positions: (19, 11, 15) | Encrypted message: GBCGV
# Positions: (19, 11, 16) | Encrypted message: LZPLG
# Positions: (19, 11, 17) | Encrypted message: MCXML
# Positions: (19, 11, 18) | Encrypted message: OPEOO
# Positions: (19, 11, 19) | Encrypted message: BXQZB
# Positions: (19, 11, 20) | Encrypted message: ZEYCZ
# Positions: (19, 11, 21) | Encrypted message: CDJPC
# Positions: (19, 11, 22) | Encrypted message: PDJPC
# Positions: (19, 11, 23) | Encrypted message: XYAXP
# Positions: (19, 11, 24) | Encrypted message: EJTEX
# Positions: (19, 11, 25) | Encrypted message: QANQE
# Positions: (19, 12, 0) | Encrypted message: SUPGG
# Positions: (19, 12, 1) | Encrypted message: HWXLL
# Positions: (19, 12, 2) | Encrypted message: FSEMM
# Positions: (19, 12, 3) | Encrypted message: RHQOO
# Positions: (19, 12, 4) | Encrypted message: KFDBB
# Positions: (19, 12, 5) | Encrypted message: IRYZZ
# Positions: (19, 12, 6) | Encrypted message: VKJCC
# Positions: (19, 12, 7) | Encrypted message: GIAPP
# Positions: (19, 12, 8) | Encrypted message: LVTXX
# Positions: (19, 12, 9) | Encrypted message: MGNEE
# Positions: (19, 12, 10) | Encrypted message: OLUQQ
# Positions: (19, 12, 11) | Encrypted message: BMWDD
# Positions: (19, 12, 12) | Encrypted message: ZOSYY
# Positions: (19, 12, 13) | Encrypted message: CBHJJ
# Positions: (19, 12, 14) | Encrypted message: PZFAA
# Positions: (19, 12, 15) | Encrypted message: XCRTT
# Positions: (19, 12, 16) | Encrypted message: EPKNN
# Positions: (19, 12, 17) | Encrypted message: QXIUU
# Positions: (19, 12, 18) | Encrypted message: DEVWS
# Positions: (19, 12, 19) | Encrypted message: YQGHH
# Positions: (19, 12, 20) | Encrypted message: JDMFF
# Positions: (19, 12, 21) | Encrypted message: AJORR
# Positions: (19, 12, 22) | Encrypted message: TJORR
# Positions: (19, 12, 23) | Encrypted message: NABKK
# Positions: (19, 12, 24) | Encrypted message: UTZII
# Positions: (19, 12, 25) | Encrypted message: WNCVV
# Positions: (19, 13, 0) | Encrypted message: EGOKS
# Positions: (19, 13, 1) | Encrypted message: QLBIH
# Positions: (19, 13, 2) | Encrypted message: DMZVF
# Positions: (19, 13, 3) | Encrypted message: YOCGR
# Positions: (19, 13, 4) | Encrypted message: JBPLK
# Positions: (19, 13, 5) | Encrypted message: AZXMI
# Positions: (19, 13, 6) | Encrypted message: TCEOV
# Positions: (19, 13, 7) | Encrypted message: NPQBG
# Positions: (19, 13, 8) | Encrypted message: UXDZL
# Positions: (19, 13, 9) | Encrypted message: WEYCM
# Positions: (19, 13, 10) | Encrypted message: SQJPO
# Positions: (19, 13, 11) | Encrypted message: HDAXB
# Positions: (19, 13, 12) | Encrypted message: FYTEZ
# Positions: (19, 13, 13) | Encrypted message: RJNQC
# Positions: (19, 13, 14) | Encrypted message: KAUDP
# Positions: (19, 13, 15) | Encrypted message: ITWYX
# Positions: (19, 13, 16) | Encrypted message: VNSJE
# Positions: (19, 13, 17) | Encrypted message: GUHAQ
# Positions: (19, 13, 18) | Encrypted message: LWFTY
# Positions: (19, 13, 19) | Encrypted message: MSRUJ
# Positions: (19, 13, 20) | Encrypted message: OHIWA
# Positions: (19, 13, 21) | Encrypted message: BRVST
# Positions: (19, 13, 22) | Encrypted message: ZRVST
# Positions: (19, 13, 23) | Encrypted message: CKGHN
# Positions: (19, 13, 24) | Encrypted message: PILFU
# Positions: (19, 13, 25) | Encrypted message: XVMRW
# Positions: (19, 14, 0) | Encrypted message: WPYNE
# Positions: (19, 14, 1) | Encrypted message: SXJUQ
# Positions: (19, 14, 2) | Encrypted message: HEAWD
# Positions: (19, 14, 3) | Encrypted message: FQTSY
# Positions: (19, 14, 4) | Encrypted message: RDNHJ
# Positions: (19, 14, 5) | Encrypted message: KYUFA
# Positions: (19, 14, 6) | Encrypted message: IJWRT
# Positions: (19, 14, 7) | Encrypted message: VASKN
# Positions: (19, 14, 8) | Encrypted message: GTHIU
# Positions: (19, 14, 9) | Encrypted message: LNFVW
# Positions: (19, 14, 10) | Encrypted message: MURGS
# Positions: (19, 14, 11) | Encrypted message: OWKLH
# Positions: (19, 14, 12) | Encrypted message: BSIMF
# Positions: (19, 14, 13) | Encrypted message: ZHVOR
# Positions: (19, 14, 14) | Encrypted message: CFGBK
# Positions: (19, 14, 15) | Encrypted message: PRLZI
# Positions: (19, 14, 16) | Encrypted message: XKMCV
# Positions: (19, 14, 17) | Encrypted message: EIOPG
# Positions: (19, 14, 18) | Encrypted message: QVBXM
# Positions: (19, 14, 19) | Encrypted message: DGZQO
# Positions: (19, 14, 20) | Encrypted message: YLPDB
# Positions: (19, 14, 21) | Encrypted message: JOXYZ
# Positions: (19, 14, 22) | Encrypted message: AOXYZ
# Positions: (19, 14, 23) | Encrypted message: TBEJC
# Positions: (19, 14, 24) | Encrypted message: NZQAP
# Positions: (19, 14, 25) | Encrypted message: UCDTX
# Positions: (19, 15, 0) | Encrypted message: FKCCZ
# Positions: (19, 15, 1) | Encrypted message: RIPPC
# Positions: (19, 15, 2) | Encrypted message: KVXXP
# Positions: (19, 15, 3) | Encrypted message: IGEEX
# Positions: (19, 15, 4) | Encrypted message: VLQQE
# Positions: (19, 15, 5) | Encrypted message: GMDDQ
# Positions: (19, 15, 6) | Encrypted message: LOYYD
# Positions: (19, 15, 7) | Encrypted message: MBJJY
# Positions: (19, 15, 8) | Encrypted message: OZAAJ
# Positions: (19, 15, 9) | Encrypted message: BCTTA
# Positions: (19, 15, 10) | Encrypted message: ZPNNT
# Positions: (19, 15, 11) | Encrypted message: CXUUN
# Positions: (19, 15, 12) | Encrypted message: PEWWU
# Positions: (19, 15, 13) | Encrypted message: XQSSW
# Positions: (19, 15, 14) | Encrypted message: EDHHS
# Positions: (19, 15, 15) | Encrypted message: QYFFH
# Positions: (19, 15, 16) | Encrypted message: DJRRF
# Positions: (19, 15, 17) | Encrypted message: YAKKR
# Positions: (19, 15, 18) | Encrypted message: JTIII
# Positions: (19, 15, 19) | Encrypted message: ANVGV
# Positions: (19, 15, 20) | Encrypted message: TULLG
# Positions: (19, 15, 21) | Encrypted message: NSMML
# Positions: (19, 15, 22) | Encrypted message: USMML
# Positions: (19, 15, 23) | Encrypted message: WHOOM
# Positions: (19, 15, 24) | Encrypted message: SFBBO
# Positions: (19, 15, 25) | Encrypted message: HRZZB
# Positions: (19, 16, 0) | Encrypted message: INJHA
# Positions: (19, 16, 1) | Encrypted message: VUAFT
# Positions: (19, 16, 2) | Encrypted message: GWTRN
# Positions: (19, 16, 3) | Encrypted message: LSNKU
# Positions: (19, 16, 4) | Encrypted message: MHUIW
# Positions: (19, 16, 5) | Encrypted message: OFWVS
# Positions: (19, 16, 6) | Encrypted message: BRSGH
# Positions: (19, 16, 7) | Encrypted message: ZKHLF
# Positions: (19, 16, 8) | Encrypted message: CIFMR
# Positions: (19, 16, 9) | Encrypted message: PVROK
# Positions: (19, 16, 10) | Encrypted message: XGKBI
# Positions: (19, 16, 11) | Encrypted message: ELIZV
# Positions: (19, 16, 12) | Encrypted message: QMVCG
# Positions: (19, 16, 13) | Encrypted message: DOGPL
# Positions: (19, 16, 14) | Encrypted message: YBLXM
# Positions: (19, 16, 15) | Encrypted message: JZMEO
# Positions: (19, 16, 16) | Encrypted message: ACOQB
# Positions: (19, 16, 17) | Encrypted message: TPBDZ
# Positions: (19, 16, 18) | Encrypted message: NXZYP
# Positions: (19, 16, 19) | Encrypted message: UECAX
# Positions: (19, 16, 20) | Encrypted message: WQXTE
# Positions: (19, 16, 21) | Encrypted message: SYENQ
# Positions: (19, 16, 22) | Encrypted message: HYENQ
# Positions: (19, 16, 23) | Encrypted message: FJQUD
# Positions: (19, 16, 24) | Encrypted message: RADWY
# Positions: (19, 16, 25) | Encrypted message: KTYSJ
# Positions: (19, 17, 0) | Encrypted message: MCFQX
# Positions: (19, 17, 1) | Encrypted message: OPRDE
# Positions: (19, 17, 2) | Encrypted message: BXKYQ
# Positions: (19, 17, 3) | Encrypted message: ZEIJD
# Positions: (19, 17, 4) | Encrypted message: CQVAY
# Positions: (19, 17, 5) | Encrypted message: PDGTJ
# Positions: (19, 17, 6) | Encrypted message: XYLNA
# Positions: (19, 17, 7) | Encrypted message: EJMUT
# Positions: (19, 17, 8) | Encrypted message: QAOWN
# Positions: (19, 17, 9) | Encrypted message: DTBSU
# Positions: (19, 17, 10) | Encrypted message: YNZHW
# Positions: (19, 17, 11) | Encrypted message: JUCFS
# Positions: (19, 17, 12) | Encrypted message: AWPRH
# Positions: (19, 17, 13) | Encrypted message: TSXKF
# Positions: (19, 17, 14) | Encrypted message: NHEIR
# Positions: (19, 17, 15) | Encrypted message: UFQVK
# Positions: (19, 17, 16) | Encrypted message: WRDGI
# Positions: (19, 17, 17) | Encrypted message: SKYLV
# Positions: (19, 17, 18) | Encrypted message: HIJML
# Positions: (19, 17, 19) | Encrypted message: FVABM
# Positions: (19, 17, 20) | Encrypted message: RGNZO
# Positions: (19, 17, 21) | Encrypted message: KMUCB
# Positions: (19, 17, 22) | Encrypted message: IMUCB
# Positions: (19, 17, 23) | Encrypted message: VOWPZ
# Positions: (19, 17, 24) | Encrypted message: GBSXC
# Positions: (19, 17, 25) | Encrypted message: LZHEP
# Positions: (19, 18, 0) | Encrypted message: YMDOT
# Positions: (19, 18, 1) | Encrypted message: JOYBN
# Positions: (19, 18, 2) | Encrypted message: ABJZU
# Positions: (19, 18, 3) | Encrypted message: TZACW
# Positions: (19, 18, 4) | Encrypted message: NCTPS
# Positions: (19, 18, 5) | Encrypted message: UPNXH
# Positions: (19, 18, 6) | Encrypted message: WXUEF
# Positions: (19, 18, 7) | Encrypted message: SEWQR
# Positions: (19, 18, 8) | Encrypted message: HQSDK
# Positions: (19, 18, 9) | Encrypted message: FDHYI
# Positions: (19, 18, 10) | Encrypted message: RYFJV
# Positions: (19, 18, 11) | Encrypted message: KJRAG
# Positions: (19, 18, 12) | Encrypted message: IAKTL
# Positions: (19, 18, 13) | Encrypted message: VTINM
# Positions: (19, 18, 14) | Encrypted message: GNVUO
# Positions: (19, 18, 15) | Encrypted message: LUGWB
# Positions: (19, 18, 16) | Encrypted message: MWLSZ
# Positions: (19, 18, 17) | Encrypted message: OSMHC
# Positions: (19, 18, 18) | Encrypted message: BHOFX
# Positions: (19, 18, 19) | Encrypted message: ZFBKE
# Positions: (19, 18, 20) | Encrypted message: CRCIQ
# Positions: (19, 18, 21) | Encrypted message: PIPVD
# Positions: (19, 18, 22) | Encrypted message: XIPVD
# Positions: (19, 18, 23) | Encrypted message: EVXGY
# Positions: (19, 18, 24) | Encrypted message: QGELJ
# Positions: (19, 18, 25) | Encrypted message: DLQMA
# Positions: (19, 19, 0) | Encrypted message: XDHUK
# Positions: (19, 19, 1) | Encrypted message: EYFWI
# Positions: (19, 19, 2) | Encrypted message: QJRSV
# Positions: (19, 19, 3) | Encrypted message: DAKHG
# Positions: (19, 19, 4) | Encrypted message: YTIFL
# Positions: (19, 19, 5) | Encrypted message: JNVRM
# Positions: (19, 19, 6) | Encrypted message: AUGKO
# Positions: (19, 19, 7) | Encrypted message: TWLIB
# Positions: (19, 19, 8) | Encrypted message: NSMVZ
# Positions: (19, 19, 9) | Encrypted message: UHOGC
# Positions: (19, 19, 10) | Encrypted message: WFBLP
# Positions: (19, 19, 11) | Encrypted message: SRZMX
# Positions: (19, 19, 12) | Encrypted message: HKCOE
# Positions: (19, 19, 13) | Encrypted message: FIPBQ
# Positions: (19, 19, 14) | Encrypted message: RVXZD
# Positions: (19, 19, 15) | Encrypted message: KGECY
# Positions: (19, 19, 16) | Encrypted message: ILQPJ
# Positions: (19, 19, 17) | Encrypted message: VMDXA
# Positions: (19, 19, 18) | Encrypted message: GOYEN
# Positions: (19, 19, 19) | Encrypted message: LBJDU
# Positions: (19, 19, 20) | Encrypted message: MZTYW
# Positions: (19, 19, 21) | Encrypted message: OPNJS
# Positions: (19, 19, 22) | Encrypted message: BPNJS
# Positions: (19, 19, 23) | Encrypted message: ZXUAH
# Positions: (19, 19, 24) | Encrypted message: CEWTF
# Positions: (19, 19, 25) | Encrypted message: PQSNR
# Positions: (19, 20, 0) | Encrypted message: KZKSJ
# Positions: (19, 20, 1) | Encrypted message: ICIHA
# Positions: (19, 20, 2) | Encrypted message: VPVFT
# Positions: (19, 20, 3) | Encrypted message: GXGRN
# Positions: (19, 20, 4) | Encrypted message: LELKU
# Positions: (19, 20, 5) | Encrypted message: MQMIW
# Positions: (19, 20, 6) | Encrypted message: ODOVS
# Positions: (19, 20, 7) | Encrypted message: BYBGH
# Positions: (19, 20, 8) | Encrypted message: ZJZLF
# Positions: (19, 20, 9) | Encrypted message: CACMR
# Positions: (19, 20, 10) | Encrypted message: PTPOK
# Positions: (19, 20, 11) | Encrypted message: XNXBI
# Positions: (19, 20, 12) | Encrypted message: EUEZV
# Positions: (19, 20, 13) | Encrypted message: QWQCG
# Positions: (19, 20, 14) | Encrypted message: DSDPL
# Positions: (19, 20, 15) | Encrypted message: YHYXM
# Positions: (19, 20, 16) | Encrypted message: JFJEO
# Positions: (19, 20, 17) | Encrypted message: ARAQB
# Positions: (19, 20, 18) | Encrypted message: TKTDC
# Positions: (19, 20, 19) | Encrypted message: NINJP
# Positions: (19, 20, 20) | Encrypted message: UVWAX
# Positions: (19, 20, 21) | Encrypted message: WLSTE
# Positions: (19, 20, 22) | Encrypted message: SLSTE
# Positions: (19, 20, 23) | Encrypted message: HMHNQ
# Positions: (19, 20, 24) | Encrypted message: FOFUD
# Positions: (19, 20, 25) | Encrypted message: RBRWY
# Positions: (19, 21, 0) | Encrypted message: HYGMR
# Positions: (19, 21, 1) | Encrypted message: FJLOK
# Positions: (19, 21, 2) | Encrypted message: RAMBI
# Positions: (19, 21, 3) | Encrypted message: KTOZV
# Positions: (19, 21, 4) | Encrypted message: INBCG
# Positions: (19, 21, 5) | Encrypted message: VUZPL
# Positions: (19, 21, 6) | Encrypted message: GWCXM
# Positions: (19, 21, 7) | Encrypted message: LSPEO
# Positions: (19, 21, 8) | Encrypted message: MHXQB
# Positions: (19, 21, 9) | Encrypted message: OFEDZ
# Positions: (19, 21, 10) | Encrypted message: BRQYC
# Positions: (19, 21, 11) | Encrypted message: ZKDJP
# Positions: (19, 21, 12) | Encrypted message: CIYAX
# Positions: (19, 21, 13) | Encrypted message: PVJTE
# Positions: (19, 21, 14) | Encrypted message: XGANQ
# Positions: (19, 21, 15) | Encrypted message: ELTUD
# Positions: (19, 21, 16) | Encrypted message: QMNWY
# Positions: (19, 21, 17) | Encrypted message: DOUSJ
# Positions: (19, 21, 18) | Encrypted message: YBWHT
# Positions: (19, 21, 19) | Encrypted message: JZSRN
# Positions: (19, 21, 20) | Encrypted message: ACFKU
# Positions: (19, 21, 21) | Encrypted message: TXRIW
# Positions: (19, 21, 22) | Encrypted message: NXRIW
# Positions: (19, 21, 23) | Encrypted message: UEKVS
# Positions: (19, 21, 24) | Encrypted message: WQIGH
# Positions: (19, 21, 25) | Encrypted message: SDVLF
# Positions: (19, 22, 0) | Encrypted message: JHBEV
# Positions: (19, 22, 1) | Encrypted message: AFZQG
# Positions: (19, 22, 2) | Encrypted message: TRCDL
# Positions: (19, 22, 3) | Encrypted message: NKPYM
# Positions: (19, 22, 4) | Encrypted message: UIXJO
# Positions: (19, 22, 5) | Encrypted message: WVEAB
# Positions: (19, 22, 6) | Encrypted message: SGQTZ
# Positions: (19, 22, 7) | Encrypted message: HLDNC
# Positions: (19, 22, 8) | Encrypted message: FMYUP
# Positions: (19, 22, 9) | Encrypted message: ROJWX
# Positions: (19, 22, 10) | Encrypted message: KBASE
# Positions: (19, 22, 11) | Encrypted message: IZTHQ
# Positions: (19, 22, 12) | Encrypted message: VCNFD
# Positions: (19, 22, 13) | Encrypted message: GPURY
# Positions: (19, 22, 14) | Encrypted message: LXWKJ
# Positions: (19, 22, 15) | Encrypted message: MESIA
# Positions: (19, 22, 16) | Encrypted message: OQHVT
# Positions: (19, 22, 17) | Encrypted message: BDFGN
# Positions: (19, 22, 18) | Encrypted message: ZYRLW
# Positions: (19, 22, 19) | Encrypted message: CJKOS
# Positions: (19, 22, 20) | Encrypted message: PAVBH
# Positions: (19, 22, 21) | Encrypted message: XNGZF
# Positions: (19, 22, 22) | Encrypted message: ENGZF
# Positions: (19, 22, 23) | Encrypted message: QULCR
# Positions: (19, 22, 24) | Encrypted message: DWMPK
# Positions: (19, 22, 25) | Encrypted message: YSOXI
# Positions: (19, 23, 0) | Encrypted message: OQAVM
# Positions: (19, 23, 1) | Encrypted message: BDTGO
# Positions: (19, 23, 2) | Encrypted message: ZYNLB
# Positions: (19, 23, 3) | Encrypted message: CJUMZ
# Positions: (19, 23, 4) | Encrypted message: PAWOC
# Positions: (19, 23, 5) | Encrypted message: XTSBP
# Positions: (19, 23, 6) | Encrypted message: ENHZX
# Positions: (19, 23, 7) | Encrypted message: QUFCE
# Positions: (19, 23, 8) | Encrypted message: DWRPQ
# Positions: (19, 23, 9) | Encrypted message: YSKXD
# Positions: (19, 23, 10) | Encrypted message: JHIEY
# Positions: (19, 23, 11) | Encrypted message: AFVQJ
# Positions: (19, 23, 12) | Encrypted message: TRGDA
# Positions: (19, 23, 13) | Encrypted message: NKLYT
# Positions: (19, 23, 14) | Encrypted message: UIMJN
# Positions: (19, 23, 15) | Encrypted message: WVOAU
# Positions: (19, 23, 16) | Encrypted message: SGBTW
# Positions: (19, 23, 17) | Encrypted message: HLZNS
# Positions: (19, 23, 18) | Encrypted message: FMCUF
# Positions: (19, 23, 19) | Encrypted message: ROPSR
# Positions: (19, 23, 20) | Encrypted message: KBEHK
# Positions: (19, 23, 21) | Encrypted message: ICQFI
# Positions: (19, 23, 22) | Encrypted message: VCQFI
# Positions: (19, 23, 23) | Encrypted message: GPDRV
# Positions: (19, 23, 24) | Encrypted message: LXYKG
# Positions: (19, 23, 25) | Encrypted message: MEJIL
# Positions: (19, 24, 0) | Encrypted message: USQWC
# Positions: (19, 24, 1) | Encrypted message: WHDSP
# Positions: (19, 24, 2) | Encrypted message: SFYHX
# Positions: (19, 24, 3) | Encrypted message: HRJFE
# Positions: (19, 24, 4) | Encrypted message: FKARQ
# Positions: (19, 24, 5) | Encrypted message: RITKD
# Positions: (19, 24, 6) | Encrypted message: KVNIY
# Positions: (19, 24, 7) | Encrypted message: IGUVJ
# Positions: (19, 24, 8) | Encrypted message: VLWGA
# Positions: (19, 24, 9) | Encrypted message: GMSLT
# Positions: (19, 24, 10) | Encrypted message: LOHMN
# Positions: (19, 24, 11) | Encrypted message: MBFOU
# Positions: (19, 24, 12) | Encrypted message: OZRBW
# Positions: (19, 24, 13) | Encrypted message: BCKZS
# Positions: (19, 24, 14) | Encrypted message: ZPICH
# Positions: (19, 24, 15) | Encrypted message: CXVPF
# Positions: (19, 24, 16) | Encrypted message: PEGXR
# Positions: (19, 24, 17) | Encrypted message: XQLEK
# Positions: (19, 24, 18) | Encrypted message: EDMQV
# Positions: (19, 24, 19) | Encrypted message: QYOYG
# Positions: (19, 24, 20) | Encrypted message: DJZJL
# Positions: (19, 24, 21) | Encrypted message: YTCAM
# Positions: (19, 24, 22) | Encrypted message: JTCAM
# Positions: (19, 24, 23) | Encrypted message: ANPTO
# Positions: (19, 24, 24) | Encrypted message: TUXNB
# Positions: (19, 24, 25) | Encrypted message: NWEUZ
# Positions: (19, 25, 0) | Encrypted message: PRVXN
# Positions: (19, 25, 1) | Encrypted message: XKGEU
# Positions: (19, 25, 2) | Encrypted message: EILQW
# Positions: (19, 25, 3) | Encrypted message: QVMDS
# Positions: (19, 25, 4) | Encrypted message: DGOYH
# Positions: (19, 25, 5) | Encrypted message: YLBJF
# Positions: (19, 25, 6) | Encrypted message: JMZAR
# Positions: (19, 25, 7) | Encrypted message: AOCTK
# Positions: (19, 25, 8) | Encrypted message: TBPNI
# Positions: (19, 25, 9) | Encrypted message: NZXUV
# Positions: (19, 25, 10) | Encrypted message: UCEWG
# Positions: (19, 25, 11) | Encrypted message: WPQSL
# Positions: (19, 25, 12) | Encrypted message: SXDHM
# Positions: (19, 25, 13) | Encrypted message: HEYFO
# Positions: (19, 25, 14) | Encrypted message: FQJRB
# Positions: (19, 25, 15) | Encrypted message: RDAKZ
# Positions: (19, 25, 16) | Encrypted message: KYTIC
# Positions: (19, 25, 17) | Encrypted message: IJNVP
# Positions: (19, 25, 18) | Encrypted message: VAUGE
# Positions: (19, 25, 19) | Encrypted message: GTWMQ
# Positions: (19, 25, 20) | Encrypted message: LNHOD
# Positions: (19, 25, 21) | Encrypted message: MWFBY
# Positions: (19, 25, 22) | Encrypted message: OWFBY
# Positions: (19, 25, 23) | Encrypted message: BSRZJ
# Positions: (19, 25, 24) | Encrypted message: ZHKCA
# Positions: (19, 25, 25) | Encrypted message: CFIPT
# Positions: (20, 0, 0) | Encrypted message: OROWN
# Positions: (20, 0, 1) | Encrypted message: BKBSU
# Positions: (20, 0, 2) | Encrypted message: ZIZHW
# Positions: (20, 0, 3) | Encrypted message: CVCFS
# Positions: (20, 0, 4) | Encrypted message: PGPRH
# Positions: (20, 0, 5) | Encrypted message: XLXKF
# Positions: (20, 0, 6) | Encrypted message: EMEIR
# Positions: (20, 0, 7) | Encrypted message: QOQVK
# ...
# Positions: (25, 13, 22) | Encrypted message: JUAHU
# Positions: (25, 13, 23) | Encrypted message: AWTFW
# Positions: (25, 13, 24) | Encrypted message: TSNRS
# Positions: (25, 13, 25) | Encrypted message: NHUKH
# Positions: (25, 14, 0) | Encrypted message: PALLD
# Positions: (25, 14, 1) | Encrypted message: XTMMY
# Positions: (25, 14, 2) | Encrypted message: ENOOJ
# Positions: (25, 14, 3) | Encrypted message: QUBBA
# Positions: (25, 14, 4) | Encrypted message: DWZZT
# Positions: (25, 14, 5) | Encrypted message: YSCCN
# Positions: (25, 14, 6) | Encrypted message: JHPPU
# Positions: (25, 14, 7) | Encrypted message: AFXXW
# Positions: (25, 14, 8) | Encrypted message: TREES
# Positions: (25, 14, 9) | Encrypted message: NKQQH
# Positions: (25, 14, 10) | Encrypted message: UIDDF
# Positions: (25, 14, 11) | Encrypted message: WVYYR
# Positions: (25, 14, 12) | Encrypted message: SGJJK
# Positions: (25, 14, 13) | Encrypted message: HLAAI
# Positions: (25, 14, 14) | Encrypted message: FMTTV
# Positions: (25, 14, 15) | Encrypted message: RONNG
# Positions: (25, 14, 16) | Encrypted message: KBUUL
# Positions: (25, 14, 17) | Encrypted message: IZWWM
# Positions: (25, 14, 18) | Encrypted message: VCSSB
# Positions: (25, 14, 19) | Encrypted message: GPHFZ
# Positions: (25, 14, 20) | Encrypted message: LXRRC
# Positions: (25, 14, 21) | Encrypted message: MQKKP
# Positions: (25, 14, 22) | Encrypted message: OQKKP
# Positions: (25, 14, 23) | Encrypted message: BDIIX
# Positions: (25, 14, 24) | Encrypted message: ZYVVE
# Positions: (25, 14, 25) | Encrypted message: CJGGQ
# Positions: (25, 15, 0) | Encrypted message: GBXZB
# Positions: (25, 15, 1) | Encrypted message: LZECZ
# Positions: (25, 15, 2) | Encrypted message: MCQPC
# Positions: (25, 15, 3) | Encrypted message: OPDXP
# Positions: (25, 15, 4) | Encrypted message: BXYEX
# Positions: (25, 15, 5) | Encrypted message: ZEJQE
# Positions: (25, 15, 6) | Encrypted message: CQADQ
# Positions: (25, 15, 7) | Encrypted message: PDTYD
# Positions: (25, 15, 8) | Encrypted message: XYNJY
# Positions: (25, 15, 9) | Encrypted message: EJUAJ
# Positions: (25, 15, 10) | Encrypted message: QAWTA
# Positions: (25, 15, 11) | Encrypted message: DTSNT
# Positions: (25, 15, 12) | Encrypted message: YNHUN
# Positions: (25, 15, 13) | Encrypted message: JUFWU
# Positions: (25, 15, 14) | Encrypted message: AWRSW
# Positions: (25, 15, 15) | Encrypted message: TSKHS
# Positions: (25, 15, 16) | Encrypted message: NHIFH
# Positions: (25, 15, 17) | Encrypted message: UFVRF
# Positions: (25, 15, 18) | Encrypted message: WRGKK
# Positions: (25, 15, 19) | Encrypted message: SKLVI
# Positions: (25, 15, 20) | Encrypted message: HIOGV
# Positions: (25, 15, 21) | Encrypted message: FGBLG
# Positions: (25, 15, 22) | Encrypted message: RGBLG
# Positions: (25, 15, 23) | Encrypted message: KLZML
# Positions: (25, 15, 24) | Encrypted message: IMCOM
# Positions: (25, 15, 25) | Encrypted message: VOPBO
# Positions: (25, 16, 0) | Encrypted message: AWITW
# Positions: (25, 16, 1) | Encrypted message: TSVNS
# Positions: (25, 16, 2) | Encrypted message: NHGUH
# Positions: (25, 16, 3) | Encrypted message: UFLWF
# Positions: (25, 16, 4) | Encrypted message: WRMSR
# Positions: (25, 16, 5) | Encrypted message: SKOHK
# Positions: (25, 16, 6) | Encrypted message: HIBFI
# Positions: (25, 16, 7) | Encrypted message: FVZRV
# Positions: (25, 16, 8) | Encrypted message: RGCKG
# Positions: (25, 16, 9) | Encrypted message: KLPIL
# Positions: (25, 16, 10) | Encrypted message: IMXVM
# Positions: (25, 16, 11) | Encrypted message: VOEGO
# Positions: (25, 16, 12) | Encrypted message: GBQLB
# Positions: (25, 16, 13) | Encrypted message: LZDMZ
# Positions: (25, 16, 14) | Encrypted message: MCYOC
# Positions: (25, 16, 15) | Encrypted message: OPJBP
# Positions: (25, 16, 16) | Encrypted message: BXAZX
# Positions: (25, 16, 17) | Encrypted message: ZETCE
# Positions: (25, 16, 18) | Encrypted message: CQNPD
# Positions: (25, 16, 19) | Encrypted message: PDUEY
# Positions: (25, 16, 20) | Encrypted message: XYSQJ
# Positions: (25, 16, 21) | Encrypted message: EAHDA
# Positions: (25, 16, 22) | Encrypted message: QAHDA
# Positions: (25, 16, 23) | Encrypted message: DTFYT
# Positions: (25, 16, 24) | Encrypted message: YNRJN
# Positions: (25, 16, 25) | Encrypted message: JUKAU
# Positions: (25, 17, 0) | Encrypted message: NXUDH
# Positions: (25, 17, 1) | Encrypted message: UEWYF
# Positions: (25, 17, 2) | Encrypted message: WQSJR
# Positions: (25, 17, 3) | Encrypted message: SDHAK
# Positions: (25, 17, 4) | Encrypted message: HYFTI
# Positions: (25, 17, 5) | Encrypted message: FJRNV
# Positions: (25, 17, 6) | Encrypted message: RAKUG
# Positions: (25, 17, 7) | Encrypted message: KTIWL
# Positions: (25, 17, 8) | Encrypted message: INVSM
# Positions: (25, 17, 9) | Encrypted message: VUGHO
# Positions: (25, 17, 10) | Encrypted message: GWLFB
# Positions: (25, 17, 11) | Encrypted message: LSMRZ
# Positions: (25, 17, 12) | Encrypted message: MHOKC
# Positions: (25, 17, 13) | Encrypted message: OFBIP
# Positions: (25, 17, 14) | Encrypted message: BRZVX
# Positions: (25, 17, 15) | Encrypted message: ZKCGE
# Positions: (25, 17, 16) | Encrypted message: CIPLQ
# Positions: (25, 17, 17) | Encrypted message: PVXMD
# Positions: (25, 17, 18) | Encrypted message: XGEOJ
# Positions: (25, 17, 19) | Encrypted message: ELQZA
# Positions: (25, 17, 20) | Encrypted message: QMYCT
# Positions: (25, 17, 21) | Encrypted message: DBJPN
# Positions: (25, 17, 22) | Encrypted message: YBJPN
# Positions: (25, 17, 23) | Encrypted message: JZAXU
# Positions: (25, 17, 24) | Encrypted message: ACTEW
# Positions: (25, 17, 25) | Encrypted message: TPNQS
# Positions: (25, 18, 0) | Encrypted message: VLPGO
# Positions: (25, 18, 1) | Encrypted message: GMXLB
# Positions: (25, 18, 2) | Encrypted message: LOEMZ
# Positions: (25, 18, 3) | Encrypted message: MBQOC
# Positions: (25, 18, 4) | Encrypted message: OZDBP
# Positions: (25, 18, 5) | Encrypted message: BCYZX
# Positions: (25, 18, 6) | Encrypted message: ZPJCE
# Positions: (25, 18, 7) | Encrypted message: CXAPQ
# Positions: (25, 18, 8) | Encrypted message: PETXD
# Positions: (25, 18, 9) | Encrypted message: XQNEY
# Positions: (25, 18, 10) | Encrypted message: EDUQJ
# Positions: (25, 18, 11) | Encrypted message: QYWDA
# Positions: (25, 18, 12) | Encrypted message: DJSYT
# Positions: (25, 18, 13) | Encrypted message: YAHJN
# Positions: (25, 18, 14) | Encrypted message: JTFAU
# Positions: (25, 18, 15) | Encrypted message: ANRTW
# Positions: (25, 18, 16) | Encrypted message: TUKNS
# Positions: (25, 18, 17) | Encrypted message: NWIUH
# Positions: (25, 18, 18) | Encrypted message: USVWR
# Positions: (25, 18, 19) | Encrypted message: WHGHK
# Positions: (25, 18, 20) | Encrypted message: SFMFI
# Positions: (25, 18, 21) | Encrypted message: HKORV
# Positions: (25, 18, 22) | Encrypted message: FKORV
# Positions: (25, 18, 23) | Encrypted message: RIBKG
# Positions: (25, 18, 24) | Encrypted message: KVZIL
# Positions: (25, 18, 25) | Encrypted message: IGCVM
# Positions: (25, 19, 0) | Encrypted message: CTOKQ
# Positions: (25, 19, 1) | Encrypted message: PNBID
# Positions: (25, 19, 2) | Encrypted message: XUZVY
# Positions: (25, 19, 3) | Encrypted message: EWCGJ
# Positions: (25, 19, 4) | Encrypted message: QSPLA
# Positions: (25, 19, 5) | Encrypted message: DHXMT
# Positions: (25, 19, 6) | Encrypted message: YFEON
# Positions: (25, 19, 7) | Encrypted message: JRQBU
# Positions: (25, 19, 8) | Encrypted message: AKDZW
# Positions: (25, 19, 9) | Encrypted message: TIYCS
# Positions: (25, 19, 10) | Encrypted message: NVJPH
# Positions: (25, 19, 11) | Encrypted message: UGAXF
# Positions: (25, 19, 12) | Encrypted message: WLTER
# Positions: (25, 19, 13) | Encrypted message: SMNQK
# Positions: (25, 19, 14) | Encrypted message: HOUDI
# Positions: (25, 19, 15) | Encrypted message: FBWYV
# Positions: (25, 19, 16) | Encrypted message: RZSJG
# Positions: (25, 19, 17) | Encrypted message: KCHAL
# Positions: (25, 19, 18) | Encrypted message: IPFTO
# Positions: (25, 19, 19) | Encrypted message: VXRUB
# Positions: (25, 19, 20) | Encrypted message: GEIWZ
# Positions: (25, 19, 21) | Encrypted message: LDVSC
# Positions: (25, 19, 22) | Encrypted message: MDVSC
# Positions: (25, 19, 23) | Encrypted message: OYGHP
# Positions: (25, 19, 24) | Encrypted message: BJLFX
# Positions: (25, 19, 25) | Encrypted message: ZAMRE
# Positions: (25, 20, 0) | Encrypted message: RUYNG
# Positions: (25, 20, 1) | Encrypted message: KWJUL
# Positions: (25, 20, 2) | Encrypted message: ISAWM
# Positions: (25, 20, 3) | Encrypted message: VHTSO
# Positions: (25, 20, 4) | Encrypted message: GFNHB
# Positions: (25, 20, 5) | Encrypted message: LRUFZ
# Positions: (25, 20, 6) | Encrypted message: MKWRC
# Positions: (25, 20, 7) | Encrypted message: OISKP
# Positions: (25, 20, 8) | Encrypted message: BVHIX
# Positions: (25, 20, 9) | Encrypted message: ZGFVE
# Positions: (25, 20, 10) | Encrypted message: CLRGQ
# Positions: (25, 20, 11) | Encrypted message: PMKLD
# Positions: (25, 20, 12) | Encrypted message: XOIMY
# Positions: (25, 20, 13) | Encrypted message: EBVOJ
# Positions: (25, 20, 14) | Encrypted message: QZGBA
# Positions: (25, 20, 15) | Encrypted message: DCLZT
# Positions: (25, 20, 16) | Encrypted message: YPMCN
# Positions: (25, 20, 17) | Encrypted message: JXOPU
# Positions: (25, 20, 18) | Encrypted message: AEBXS
# Positions: (25, 20, 19) | Encrypted message: TQZQH
# Positions: (25, 20, 20) | Encrypted message: NDPDF
# Positions: (25, 20, 21) | Encrypted message: UJXYR
# Positions: (25, 20, 22) | Encrypted message: WJXYR
# Positions: (25, 20, 23) | Encrypted message: SAEJK
# Positions: (25, 20, 24) | Encrypted message: HTQAI
# Positions: (25, 20, 25) | Encrypted message: FNDTV
# Positions: (25, 21, 0) | Encrypted message: TGCCS
# Positions: (25, 21, 1) | Encrypted message: NLPPH
# Positions: (25, 21, 2) | Encrypted message: UMXXF
# Positions: (25, 21, 3) | Encrypted message: WOEER
# Positions: (25, 21, 4) | Encrypted message: SBQQK
# Positions: (25, 21, 5) | Encrypted message: HZDDI
# Positions: (25, 21, 6) | Encrypted message: FCYYV
# Positions: (25, 21, 7) | Encrypted message: RPJJG
# Positions: (25, 21, 8) | Encrypted message: KXAAL
# Positions: (25, 21, 9) | Encrypted message: IETTM
# Positions: (25, 21, 10) | Encrypted message: VQNNO
# Positions: (25, 21, 11) | Encrypted message: GDUUB
# Positions: (25, 21, 12) | Encrypted message: LYWWZ
# Positions: (25, 21, 13) | Encrypted message: MJSSC
# Positions: (25, 21, 14) | Encrypted message: OAHHP
# Positions: (25, 21, 15) | Encrypted message: BTFFX
# Positions: (25, 21, 16) | Encrypted message: ZNRRE
# Positions: (25, 21, 17) | Encrypted message: CUKKQ
# Positions: (25, 21, 18) | Encrypted message: PWIIY
# Positions: (25, 21, 19) | Encrypted message: XSVGJ
# Positions: (25, 21, 20) | Encrypted message: EHLLA
# Positions: (25, 21, 21) | Encrypted message: QRMMT
# Positions: (25, 21, 22) | Encrypted message: DRMMT
# Positions: (25, 21, 23) | Encrypted message: YKOON
# Positions: (25, 21, 24) | Encrypted message: JIBBU
# Positions: (25, 21, 25) | Encrypted message: AVZZW
# Positions: (25, 22, 0) | Encrypted message: ZPJHE
# Positions: (25, 22, 1) | Encrypted message: CXAFQ
# Positions: (25, 22, 2) | Encrypted message: PETRD
# Positions: (25, 22, 3) | Encrypted message: XQNKY
# Positions: (25, 22, 4) | Encrypted message: EDUIJ
# Positions: (25, 22, 5) | Encrypted message: QYWVA
# Positions: (25, 22, 6) | Encrypted message: DJSGT
# Positions: (25, 22, 7) | Encrypted message: YAHLN
# Positions: (25, 22, 8) | Encrypted message: JTFMU
# Positions: (25, 22, 9) | Encrypted message: ANROW
# Positions: (25, 22, 10) | Encrypted message: TUKBS
# Positions: (25, 22, 11) | Encrypted message: NWIZH
# Positions: (25, 22, 12) | Encrypted message: USVCF
# Positions: (25, 22, 13) | Encrypted message: WHGPR
# Positions: (25, 22, 14) | Encrypted message: SFLXK
# Positions: (25, 22, 15) | Encrypted message: HRMEI
# Positions: (25, 22, 16) | Encrypted message: FKOQV
# Positions: (25, 22, 17) | Encrypted message: RIBDG
# Positions: (25, 22, 18) | Encrypted message: KVZYM
# Positions: (25, 22, 19) | Encrypted message: IGCAO
# Positions: (25, 22, 20) | Encrypted message: VLXTB
# Positions: (25, 22, 21) | Encrypted message: GOENZ
# Positions: (25, 22, 22) | Encrypted message: LOENZ
# Positions: (25, 22, 23) | Encrypted message: MBQUC
# Positions: (25, 22, 24) | Encrypted message: OZDWP
# Positions: (25, 22, 25) | Encrypted message: BCYSX
# Positions: (25, 23, 0) | Encrypted message: LKFQZ
# Positions: (25, 23, 1) | Encrypted message: MIRDC
# Positions: (25, 23, 2) | Encrypted message: OVKYP
# Positions: (25, 23, 3) | Encrypted message: BGIJX
# Positions: (25, 23, 4) | Encrypted message: ZLVAE
# Positions: (25, 23, 5) | Encrypted message: CMGTQ
# Positions: (25, 23, 6) | Encrypted message: POLND
# Positions: (25, 23, 7) | Encrypted message: XBMUY
# Positions: (25, 23, 8) | Encrypted message: EZOWJ
# Positions: (25, 23, 9) | Encrypted message: QCBSA
# Positions: (25, 23, 10) | Encrypted message: DPZHT
# Positions: (25, 23, 11) | Encrypted message: YXCFN
# Positions: (25, 23, 12) | Encrypted message: JEPRU
# Positions: (25, 23, 13) | Encrypted message: AQXKW
# Positions: (25, 23, 14) | Encrypted message: TDEIS
# Positions: (25, 23, 15) | Encrypted message: NYQVH
# Positions: (25, 23, 16) | Encrypted message: UJDGF
# Positions: (25, 23, 17) | Encrypted message: WAYLR
# Positions: (25, 23, 18) | Encrypted message: STJMI
# Positions: (25, 23, 19) | Encrypted message: HNABV
# Positions: (25, 23, 20) | Encrypted message: FUNZG
# Positions: (25, 23, 21) | Encrypted message: RSUCL
# Positions: (25, 23, 22) | Encrypted message: KSUCL
# Positions: (25, 23, 23) | Encrypted message: IHWPM
# Positions: (25, 23, 24) | Encrypted message: VFSXO
# Positions: (25, 23, 25) | Encrypted message: GRHEB
# Positions: (25, 24, 0) | Encrypted message: QNDOA
# Positions: (25, 24, 1) | Encrypted message: DUYBT
# Positions: (25, 24, 2) | Encrypted message: YWJZN
# Positions: (25, 24, 3) | Encrypted message: JSACU
# Positions: (25, 24, 4) | Encrypted message: AHTPW
# Positions: (25, 24, 5) | Encrypted message: TFNXS
# Positions: (25, 24, 6) | Encrypted message: NRUEH
# Positions: (25, 24, 7) | Encrypted message: UKWQF
# Positions: (25, 24, 8) | Encrypted message: WISDR
# Positions: (25, 24, 9) | Encrypted message: SVHYK
# Positions: (25, 24, 10) | Encrypted message: HGFJI
# Positions: (25, 24, 11) | Encrypted message: FLRAV
# Positions: (25, 24, 12) | Encrypted message: RMKTG
# Positions: (25, 24, 13) | Encrypted message: KOINL
# Positions: (25, 24, 14) | Encrypted message: IBVUM
# Positions: (25, 24, 15) | Encrypted message: VZGWO
# Positions: (25, 24, 16) | Encrypted message: GCLSB
# Positions: (25, 24, 17) | Encrypted message: LPMHZ
# Positions: (25, 24, 18) | Encrypted message: MXOFP
# Positions: (25, 24, 19) | Encrypted message: OEBKX
# Positions: (25, 24, 20) | Encrypted message: BQCIE
# Positions: (25, 24, 21) | Encrypted message: ZYPVQ
# Positions: (25, 24, 22) | Encrypted message: CYPVQ
# Positions: (25, 24, 23) | Encrypted message: PJXGD
# Positions: (25, 24, 24) | Encrypted message: XAELY
# Positions: (25, 24, 25) | Encrypted message: ETQMJ
# Positions: (25, 25, 0) | Encrypted message: BCHUX
# Positions: (25, 25, 1) | Encrypted message: ZPFWE
# Positions: (25, 25, 2) | Encrypted message: CXRSQ
# Positions: (25, 25, 3) | Encrypted message: PEKHD
# Positions: (25, 25, 4) | Encrypted message: XQIFY
# Positions: (25, 25, 5) | Encrypted message: EDVRJ
# Positions: (25, 25, 6) | Encrypted message: QYGKA
# Positions: (25, 25, 7) | Encrypted message: DJLIT
# Positions: (25, 25, 8) | Encrypted message: YAMVN
# Positions: (25, 25, 9) | Encrypted message: JTOGU
# Positions: (25, 25, 10) | Encrypted message: ANBLW
# Positions: (25, 25, 11) | Encrypted message: TUZMS
# Positions: (25, 25, 12) | Encrypted message: NWCOH
# Positions: (25, 25, 13) | Encrypted message: USPBF
# Positions: (25, 25, 14) | Encrypted message: WHXZR
# Positions: (25, 25, 15) | Encrypted message: SFECK
# Positions: (25, 25, 16) | Encrypted message: HRQPI
# Positions: (25, 25, 17) | Encrypted message: FKDXV
# Positions: (25, 25, 18) | Encrypted message: RIYEL
# Positions: (25, 25, 19) | Encrypted message: KVJDM
# Positions: (25, 25, 20) | Encrypted message: IGTYO
# Positions: (25, 25, 21) | Encrypted message: VMNJB
# Positions: (25, 25, 22) | Encrypted message: GMNJB
# Positions: (25, 25, 23) | Encrypted message: LOUAZ
# Positions: (25, 25, 24) | Encrypted message: MBWTC
# Positions: (25, 25, 25) | Encrypted message: OZSNP
